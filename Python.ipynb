# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnanandMorningstar/1st-demo/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Krishna")
# Out:
# Hello Krishna

# %%
print ('How are you')
# Out:
# How are you

# %%
print('if x=10 and y=20, then what is x+y')
# Out:
# if x=10 and y=20, then what is x+y

# %%
import pandas as pd

# %% [markdown]
# # New section
